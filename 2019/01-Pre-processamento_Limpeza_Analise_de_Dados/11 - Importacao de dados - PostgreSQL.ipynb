# %%
import psycopg2 as pg
import pandas.io.sql as psql

passwd = ''
conn = pg.connect(host='localhost', dbname='empresa', user='postgres', password=passwd)
sql = "select * from funcionario"
df = psql.read_sql(sql, conn)

# %%
df
# Out:
#       pnome minicial    unome          cpf    datanasc  \
# 0     Joice        A    Leite  45345345376  1972-07-31
# 1     André        V  Pereira  98798798733  1969-03-29
# 2     Jorge        E    Brito  88866555576  1937-11-10
# 3  Fernando        T     Wong  33344555587  1955-12-08
# 4  Jennifer        S    Souza  98765432168  1941-06-20
# 5      João        B    Silva  12345678966  1965-01-09
# 6     Alice        J   Zelaya  99988777767  1968-01-19
# 7   Ronaldo        K     Lima  66688444476  1962-09-15
#
#                                   endereco sexo  salario cpf_supervisor  dnr
# 0         Av. Lucas Obes, 74,São Paulo, SP    F  25000.0    33344555587  NaN
# 1            Rua Timbira, 35,São Paulo, SP    M  25000.0    98765432168  NaN
# 2           Rua do Horto, 35,São Paulo, SP    M  55000.0           None  1.0
# 3           Rua da lapa, 34, Sao Paulo, SP    M  40000.0    88866555576  5.0
# 4  Av. Arthur de Lima, 54, Santo Andre, SP    F  43000.0    88866555576  4.0
# ...
